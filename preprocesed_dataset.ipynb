# %% [markdown]
# ## Import Library & Dependencies

# %%
import pandas as pd
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %% [markdown]
# ## Text Preprocessing

# %% [markdown]
# ### Case Folding

# %%
def caseFolding(data):
    return data.applymap(lambda s: s.lower() if type(s) == str else s)
    # print(df2)

# %% [markdown]
# ### Punctuation

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punctuation(text):
    no_punct=[words for words in text if words not in string.punctuation]
    words_wo_punct=''.join(no_punct)
    return words_wo_punct

# %%
import re

# %% [markdown]
# ### Tokenize

# %%
def tokenize(text):
    split=re.split("\W+",text) 
    return split

# %% [markdown]
# ### Stopword

# %%
file= open("./NLP_bahasa_resources/combined_stop_words.txt").read().splitlines()
  
# reading the file
stopwords = file

# %%
def remove_stopwords(text):
    text=[word for word in text if word not in stopwords]
    return text

# %%
def get_stemm(text):
    #Record stemmer dalam variable
    factory = StemmerFactory()
    #buat sebuah data stemmer 
    stemmer = factory.create_stemmer()
    text=[stemmer.stem(word) for word in text]
    return text

# %% [markdown]
# ## Data Processing

# %%
from simpledbf import Dbf5

# %%
dbf = Dbf5("./data/KBLI_DES.DBF")

# %%
kbli_des = dbf.to_dataframe()

# %%
kbli_des = kbli_des.rename(columns = {"B1R11A": "nama_usaha",
                           "B1R15A":"kategori_usaha",
                           "B1R15A_KOD":"kode_kategori",
                           "B1R15B":"output_usaha",
                           "B1R15B_KOD":"kode_kelompok"})

# %%
kbli_des = caseFolding(kbli_des)

# %%
feature=kbli_des[["kategori_usaha", "output_usaha","kode_kategori","kode_kelompok"]]

# %%
feature
# Out:
#                                kategori_usaha              output_usaha  \
# 0                    jual beli sarana upacara         banten dari janur
# 1                      menjual makanan ringan            makanan ringan
# 2                      ukir sanggah dari kayu               ukiran kayu
# 3                      menjual makanan ringan            makanan ringan
# 4                           jual minuman kopi              minuman kopi
# ...                                       ...                       ...
# 394518                    praktik doktor umum  jasa praktik doktor umum
# 394519       menjahit pakaian yang diinginkan     jasa menjahit pakaian
# 394520                      menjual gas epiji                gas elpiji
# 394521       menjual eceran sembako di warung       makanan dan minuman
# 394522  menyablon baju sesuai yang diinginkan          jasa sablon baju
#
#        kode_kategori kode_kelompok
# 0                  c         16292
# 1                  g         47112
# 2                  c         16221
# 3                  g         47112
# 4                  i         56306
# ...              ...           ...
# 394518             q         86201
# 394519             c         14120
# 394520             g         47772
# 394521             g         47112
# 394522             c         14111
#
# [394523 rows x 4 columns]

# %%
feature["text"] = feature["kategori_usaha"] + " " + feature["output_usaha"]

# %%
feature["punctuation"] = feature["text"].apply(lambda x : remove_punctuation(str(x)))

# %%
feature
# Out:
#                                kategori_usaha              output_usaha  \
# 0                    jual beli sarana upacara         banten dari janur
# 1                      menjual makanan ringan            makanan ringan
# 2                      ukir sanggah dari kayu               ukiran kayu
# 3                      menjual makanan ringan            makanan ringan
# 4                           jual minuman kopi              minuman kopi
# ...                                       ...                       ...
# 394518                    praktik doktor umum  jasa praktik doktor umum
# 394519       menjahit pakaian yang diinginkan     jasa menjahit pakaian
# 394520                      menjual gas epiji                gas elpiji
# 394521       menjual eceran sembako di warung       makanan dan minuman
# 394522  menyablon baju sesuai yang diinginkan          jasa sablon baju
#
#        kode_kategori kode_kelompok  \
# 0                  c         16292
# 1                  g         47112
# 2                  c         16221
# 3                  g         47112
# 4                  i         56306
# ...              ...           ...
# 394518             q         86201
# 394519             c         14120
# 394520             g         47772
# 394521             g         47112
# 394522             c         14111
#
#                                                      text  \
# 0              jual beli sarana upacara banten dari janur
# 1                   menjual makanan ringan makanan ringan
# 2                      ukir sanggah dari kayu ukiran kayu
# 3                   menjual makanan ringan makanan ringan
# 4                          jual minuman kopi minuman kopi
# ...                                                   ...
# 394518       praktik doktor umum jasa praktik doktor umum
# 394519  menjahit pakaian yang diinginkan jasa menjahit...
# 394520                       menjual gas epiji gas elpiji
# 394521  menjual eceran sembako di warung makanan dan m...
# 394522  menyablon baju sesuai yang diinginkan jasa sab...
#
#                                               punctuation
# 0              jual beli sarana upacara banten dari janur
# 1                   menjual makanan ringan makanan ringan
# 2                      ukir sanggah dari kayu ukiran kayu
# 3                   menjual makanan ringan makanan ringan
# 4                          jual minuman kopi minuman kopi
# ...                                                   ...
# 394518       praktik doktor umum jasa praktik doktor umum
# 394519  menjahit pakaian yang diinginkan jasa menjahit...
# 394520                       menjual gas epiji gas elpiji
# 394521  menjual eceran sembako di warung makanan dan m...
# 394522  menyablon baju sesuai yang diinginkan jasa sab...
#
# [394523 rows x 6 columns]

# %%
feature['tokenization']=feature['punctuation'].apply(lambda x: tokenize(x))

# %%
feature
# Out:
#                                kategori_usaha              output_usaha  \
# 0                    jual beli sarana upacara         banten dari janur
# 1                      menjual makanan ringan            makanan ringan
# 2                      ukir sanggah dari kayu               ukiran kayu
# 3                      menjual makanan ringan            makanan ringan
# 4                           jual minuman kopi              minuman kopi
# ...                                       ...                       ...
# 394518                    praktik doktor umum  jasa praktik doktor umum
# 394519       menjahit pakaian yang diinginkan     jasa menjahit pakaian
# 394520                      menjual gas epiji                gas elpiji
# 394521       menjual eceran sembako di warung       makanan dan minuman
# 394522  menyablon baju sesuai yang diinginkan          jasa sablon baju
#
#        kode_kategori kode_kelompok  \
# 0                  c         16292
# 1                  g         47112
# 2                  c         16221
# 3                  g         47112
# 4                  i         56306
# ...              ...           ...
# 394518             q         86201
# 394519             c         14120
# 394520             g         47772
# 394521             g         47112
# 394522             c         14111
#
#                                                      text  \
# 0              jual beli sarana upacara banten dari janur
# 1                   menjual makanan ringan makanan ringan
# 2                      ukir sanggah dari kayu ukiran kayu
# 3                   menjual makanan ringan makanan ringan
# 4                          jual minuman kopi minuman kopi
# ...                                                   ...
# 394518       praktik doktor umum jasa praktik doktor umum
# 394519  menjahit pakaian yang diinginkan jasa menjahit...
# 394520                       menjual gas epiji gas elpiji
# 394521  menjual eceran sembako di warung makanan dan m...
# 394522  menyablon baju sesuai yang diinginkan jasa sab...
#
#                                               punctuation  \
# 0              jual beli sarana upacara banten dari janur
# 1                   menjual makanan ringan makanan ringan
# 2                      ukir sanggah dari kayu ukiran kayu
# 3                   menjual makanan ringan makanan ringan
# 4                          jual minuman kopi minuman kopi
# ...                                                   ...
# 394518       praktik doktor umum jasa praktik doktor umum
# 394519  menjahit pakaian yang diinginkan jasa menjahit...
# 394520                       menjual gas epiji gas elpiji
# 394521  menjual eceran sembako di warung makanan dan m...
# 394522  menyablon baju sesuai yang diinginkan jasa sab...
#
#                                              tokenization
# 0       [jual, beli, sarana, upacara, banten, dari, ja...
# 1             [menjual, makanan, ringan, makanan, ringan]
# 2               [ukir, sanggah, dari, kayu, ukiran, kayu]
# 3             [menjual, makanan, ringan, makanan, ringan]
# 4                    [jual, minuman, kopi, minuman, kopi]
# ...                                                   ...
# 394518  [praktik, doktor, umum, jasa, praktik, doktor,...
# 394519  [menjahit, pakaian, yang, diinginkan, jasa, me...
# 394520                 [menjual, gas, epiji, gas, elpiji]
# 394521  [menjual, eceran, sembako, di, warung, makanan...
# 394522  [menyablon, baju, sesuai, yang, diinginkan, ja...
#
# [394523 rows x 7 columns]

# %%
feature['stopwords'] = feature['tokenization'].apply(lambda x : remove_stopwords(x))

# %%
feature
# Out:
#                                kategori_usaha              output_usaha  \
# 0                    jual beli sarana upacara         banten dari janur
# 1                      menjual makanan ringan            makanan ringan
# 2                      ukir sanggah dari kayu               ukiran kayu
# 3                      menjual makanan ringan            makanan ringan
# 4                           jual minuman kopi              minuman kopi
# ...                                       ...                       ...
# 394518                    praktik doktor umum  jasa praktik doktor umum
# 394519       menjahit pakaian yang diinginkan     jasa menjahit pakaian
# 394520                      menjual gas epiji                gas elpiji
# 394521       menjual eceran sembako di warung       makanan dan minuman
# 394522  menyablon baju sesuai yang diinginkan          jasa sablon baju
#
#        kode_kategori kode_kelompok  \
# 0                  c         16292
# 1                  g         47112
# 2                  c         16221
# 3                  g         47112
# 4                  i         56306
# ...              ...           ...
# 394518             q         86201
# 394519             c         14120
# 394520             g         47772
# 394521             g         47112
# 394522             c         14111
#
#                                                      text  \
# 0              jual beli sarana upacara banten dari janur
# 1                   menjual makanan ringan makanan ringan
# 2                      ukir sanggah dari kayu ukiran kayu
# 3                   menjual makanan ringan makanan ringan
# 4                          jual minuman kopi minuman kopi
# ...                                                   ...
# 394518       praktik doktor umum jasa praktik doktor umum
# 394519  menjahit pakaian yang diinginkan jasa menjahit...
# 394520                       menjual gas epiji gas elpiji
# 394521  menjual eceran sembako di warung makanan dan m...
# 394522  menyablon baju sesuai yang diinginkan jasa sab...
#
#                                               punctuation  \
# 0              jual beli sarana upacara banten dari janur
# 1                   menjual makanan ringan makanan ringan
# 2                      ukir sanggah dari kayu ukiran kayu
# 3                   menjual makanan ringan makanan ringan
# 4                          jual minuman kopi minuman kopi
# ...                                                   ...
# 394518       praktik doktor umum jasa praktik doktor umum
# 394519  menjahit pakaian yang diinginkan jasa menjahit...
# 394520                       menjual gas epiji gas elpiji
# 394521  menjual eceran sembako di warung makanan dan m...
# 394522  menyablon baju sesuai yang diinginkan jasa sab...
#
#                                              tokenization  \
# 0       [jual, beli, sarana, upacara, banten, dari, ja...
# 1             [menjual, makanan, ringan, makanan, ringan]
# 2               [ukir, sanggah, dari, kayu, ukiran, kayu]
# 3             [menjual, makanan, ringan, makanan, ringan]
# 4                    [jual, minuman, kopi, minuman, kopi]
# ...                                                   ...
# 394518  [praktik, doktor, umum, jasa, praktik, doktor,...
# 394519  [menjahit, pakaian, yang, diinginkan, jasa, me...
# 394520                 [menjual, gas, epiji, gas, elpiji]
# 394521  [menjual, eceran, sembako, di, warung, makanan...
# 394522  [menyablon, baju, sesuai, yang, diinginkan, ja...
#
#                                                 stopwords
# 0            [jual, beli, sarana, upacara, banten, janur]
# 1             [menjual, makanan, ringan, makanan, ringan]
# 2                     [ukir, sanggah, kayu, ukiran, kayu]
# 3             [menjual, makanan, ringan, makanan, ringan]
# 4                    [jual, minuman, kopi, minuman, kopi]
# ...                                                   ...
# 394518           [praktik, doktor, jasa, praktik, doktor]
# 394519       [menjahit, pakaian, jasa, menjahit, pakaian]
# 394520                 [menjual, gas, epiji, gas, elpiji]
# 394521  [menjual, eceran, sembako, warung, makanan, mi...
# 394522              [menyablon, baju, jasa, sablon, baju]
#
# [394523 rows x 8 columns]

# %%
feature['stemming'] = feature['stopwords'].apply(lambda x : get_stemm(x))

# %%
feature

# %%
feature.to_excel("feature.xlsx", index = False)
